# %% [markdown]
# <a href="https://colab.research.google.com/github/tazar09/cars_dimensions/blob/main/midsize_07-feb2024__.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import numpy as np

import warnings
warnings.filterwarnings('ignore')
import time

# %% [markdown]
# # Scrapping the website

# %%
url = 'https://www.automobiledimension.com/mid-size-suv.php'
h3 = requests.get(url, verify = False)
html_content = h3.text

# %% [markdown]
# # Creating BeautifulSoup objects

# %%
soup = BeautifulSoup(html_content, 'html.parser')
main_table = soup.find('main')

# %%
temp_list = []
for i in main_table.find_all('div', class_ = 'unit'):
  link = str(i.a['href'])
  temp_list.append('https://www.automobiledimension.com' + link)
temp_list[0:3]
# Out:
# ['https://www.automobiledimension.com/model/hyundai/kona',
#  'https://www.automobiledimension.com/model/renault/austral',
#  'https://www.automobiledimension.com/model/kia/sportage']

# %% [markdown]
# # Extract model description

# %%
def extract_main_text(text):
  search = text.find('div', class_ = 'interior-text')
  return search.text

# %%
def extract_boot_space(text):
  search = text.find_all('figcaption')[1]
  boot_space = search.text
  return boot_space

# %%
main_text_list = []
boot_space_list = []

try:
  for i in temp_list:
    content = requests.get(i, verify = False)
    time.sleep(3)
    content = BeautifulSoup(content.text, 'html.parser')
    main_text_list.append(extract_main_text(content))
    boot_space_list.append(extract_boot_space(content))
except:
  main_text_list.append(None)
  boot_space_list.append(None)

# %% [markdown]
# # Creating dataframe

# %%
df = pd.DataFrame({'description': main_text_list, 'boot_space': boot_space_list})
# df.head(100)

# %% [markdown]
# # Cleaning the dataframe

# %%
df['boot_space'] = df['boot_space'].str.replace('Boot space: ', '')
df['boot_space'] = df['boot_space'].str.replace(' liters.','')
df['boot_space'] = df['boot_space'].str.replace('*','')
df.head(100)
# Out:
#                                           description               boot_space
# 0   The Hyundai Kona has a length of 4355 mm, a he...                493 - 466
# 1   The Renault Austral has a length of 4510 mm, a...                430 - 500
# 2   The Kia Sportage has a length of 4515 mm, a he...                540 - 591
# 3   The Alfa-Romeo Tonale has a length of 4530 mm,...                      500
# 4   The Volkswagen Tiguan has a length of 4540 mm,...
# 5   The LynkCo 01 has a length of 4541 mm, a heigh...                      466
# 6   The Peugeot 3008 has a length of 4542 mm, a he...                      520
# 7   The Mitsubishi Eclipse Cross has a length of 4...                      404
# 8   The Dacia Jogger has a length of 4547 mm, a he...    (5) 565-708 - (7) 160
# 9   The BMW X2 has a length of 4554 mm, a height o...                      560
# 10  The Renault Arkana has a length of 4568 mm, a ...                480 - 513
# 11  The Mazda CX-5 has a length of 4575 mm, a heig...                      522
# 12  The Volkswagen ID.4 has a length of 4584 mm, a...                      543
# 13  The Audi Q4 e-tron has a length of 4588 mm, a ...                      520
# 14  The DS DS7 has a length of 4595 mm, a height o...                      555
# 15  The Nissan Ariya has a length of 4595 mm, a he...                      466
# 16  The Land-Rover Discovery Sport has a length of...        (5) 541 - (7) 100
# 17  The Volkswagen ID.5 has a length of 4599 mm, a...                      549
# 18  The Toyota RAV4 has a length of 4600 mm, a hei...                520 - 580
# 19  The Honda CR-V has a length of 4706 mm, a heig...                635 - 596
# 20  The Ford Kuga has a length of 4604 mm, a heigh...                      482
# 21  The MG HS has a length of 4610 mm, a height of...                448 - 463
# 22  The Mercedes-Benz GLB has a length of 4634 mm,...          (5) 570 - (7) -
# 23  The Hyundai IONIQ 5 has a length of 4635 mm, a...                      588
# 24  The Suzuki Across has a length of 4635 mm, a h...                      490
# 25  The Subaru Forester has a length of 4640 mm, a...                      509
# 26  The Peugeot 5008 has a length of 4641 mm, a he...        (5) 780 - (7) 166
# 27  The CUPRA Tavascan has a length of 4644 mm, a ...                      540
# 28  The Skoda Enyaq iV has a length of 4649 mm, a ...                      585
# 29  The Lexus NX has a length of 4660 mm, a height...                      555
# 30  The Hyundai Nexo has a length of 4670 mm, a he...                      461
# 31  The Nissan X-Trail has a length of 4680 mm, a ...  575 - (5) 585 - (7) 177
# 32  The Audi Q5 has a length of 4682 mm, a height ...                465 - 550
# 33  The Jaguar I-PACE has a length of 4682 mm, a h...                      505
# 34  The Alfa-Romeo Stelvio has a length of 4687 mm...                      525
# 35  The Subaru Solterra has a length of 4690 mm, a...                      452
# 36  The Toyota bZ4X has a length of 4690 mm, a hei...                      452

# %%
x = df.loc[31, 'boot_space']
len(x)
# Out:
# 23

# %%
def extract_5_seats_boot(text):
  # rows with only 3-digits number
  if len(text) == 3:
    return text
  # rows w/wo hybrid
  elif ('-' in text and '(5)' not in text):
    pattern1 = r'.*(\d{3})'
    match1 = re.search(pattern1, text)
    return match1.group(1).strip()
  # rows with 5 and 7 seated boot space
  elif '(5)' in text:
    pattern2 = r'\(5\)\s(\d+)'
    match2 = re.search(pattern2, text)
    return match2.group(1).strip()
  # blank and all other rows
  else:
    return ''

def extract_7_seats_boot(text):
  if '(7) ' in text:
    pattern = r'\(7\)\s(\d+)'
    match1 = re.search(pattern, text)
    if match1:
      return match1.group(1).strip()
    else:
      return ''
  else:
    return ''

def extract_5_hybrid(text):
    if ('-' in text and '(' not in text):
      first, second = text.split('-')
      first = first.strip()
      second = second.strip()
      lst1 = [first, second]
      lst1.sort()
      return lst1[0]


    elif ('(' in text and '-' in text):
       pattern = r".*(\d{3}).*(\d{3}).*(\d{3})"
       match1 = re.search(pattern, text)
       if match1:
        first = int(match1.group(1))
        second = int(match1.group(2))
        third = int(match1.group(3))
        lst2 = [first, second, third]
        lst2.sort()
        return lst2[1]
       else:
        return ''
    else:
      return ''

# %%
df['boot_space_5'] = df['boot_space'].apply(lambda x: extract_5_seats_boot(x))
df['boot_5_hybrid'] = df['boot_space'].apply(lambda x: extract_5_hybrid(x))
df['boot_space_7'] = df['boot_space'].apply(lambda x: extract_7_seats_boot(x))

df.drop('boot_space', axis = 1).head(100)
# Out:
#                                           description boot_space_5  \
# 0   The Hyundai Kona has a length of 4355 mm, a he...          466
# 1   The Renault Austral has a length of 4510 mm, a...          500
# 2   The Kia Sportage has a length of 4515 mm, a he...          591
# 3   The Alfa-Romeo Tonale has a length of 4530 mm,...          500
# 4   The Volkswagen Tiguan has a length of 4540 mm,...
# 5   The LynkCo 01 has a length of 4541 mm, a heigh...          466
# 6   The Peugeot 3008 has a length of 4542 mm, a he...          520
# 7   The Mitsubishi Eclipse Cross has a length of 4...          404
# 8   The Dacia Jogger has a length of 4547 mm, a he...          565
# 9   The BMW X2 has a length of 4554 mm, a height o...          560
# 10  The Renault Arkana has a length of 4568 mm, a ...          513
# 11  The Mazda CX-5 has a length of 4575 mm, a heig...          522
# 12  The Volkswagen ID.4 has a length of 4584 mm, a...          543
# 13  The Audi Q4 e-tron has a length of 4588 mm, a ...          520
# 14  The DS DS7 has a length of 4595 mm, a height o...          555
# 15  The Nissan Ariya has a length of 4595 mm, a he...          466
# 16  The Land-Rover Discovery Sport has a length of...          541
# 17  The Volkswagen ID.5 has a length of 4599 mm, a...          549
# 18  The Toyota RAV4 has a length of 4600 mm, a hei...          580
# 19  The Honda CR-V has a length of 4706 mm, a heig...          596
# 20  The Ford Kuga has a length of 4604 mm, a heigh...          482
# 21  The MG HS has a length of 4610 mm, a height of...          463
# 22  The Mercedes-Benz GLB has a length of 4634 mm,...          570
# 23  The Hyundai IONIQ 5 has a length of 4635 mm, a...          588
# 24  The Suzuki Across has a length of 4635 mm, a h...          490
# 25  The Subaru Forester has a length of 4640 mm, a...          509
# 26  The Peugeot 5008 has a length of 4641 mm, a he...          780
# 27  The CUPRA Tavascan has a length of 4644 mm, a ...          540
# 28  The Skoda Enyaq iV has a length of 4649 mm, a ...          585
# 29  The Lexus NX has a length of 4660 mm, a height...          555
# 30  The Hyundai Nexo has a length of 4670 mm, a he...          461
# 31  The Nissan X-Trail has a length of 4680 mm, a ...          585
# 32  The Audi Q5 has a length of 4682 mm, a height ...          550
# 33  The Jaguar I-PACE has a length of 4682 mm, a h...          505
# 34  The Alfa-Romeo Stelvio has a length of 4687 mm...          525
# 35  The Subaru Solterra has a length of 4690 mm, a...          452
# 36  The Toyota bZ4X has a length of 4690 mm, a hei...          452
#
#    boot_5_hybrid boot_space_7
# 0            466
# 1            430
# 2            540
# 3
# 4
# 5
# 6
# 7
# 8            565          160
# 9
# 10           480
# 11
# 12
# 13
# 14
# 15
# 16                        100
# 17
# 18           520
# 19           596
# 20
# 21           448
# 22
# 23
# 24
# 25
# 26                        166
# 27
# 28
# 29
# 30
# 31           575          177
# 32           465
# 33
# 34
# 35
# 36

# %%
# df['7-seated'] = df['boot_space_7'].apply(lambda x: 'Yes' if pd.notna(x) else 'No')

# def boot_hybrid(text):
#   if ('-' in text and '(' not in text):
#     match_hybrid = text.split('-')
#     return match_hybrid[0].strip()
#   else:
#     return np.NaN

# def boot_normal(text):
#   if ('-' in text and '(' not in text):
#     match_normal = text.split('-')
#     return match_normal[1].strip()
#   else:
#     return np.NaN

# # def join_boot_5_normal(text)



# df['boot_space_hydbrid'] = df['boot_space'].apply(lambda x: boot_hybrid(x))
# df['boot_space_normal'] = df['boot_space'].apply(lambda x: boot_normal(x))
# df['boot_normal_final'] = df['boot_space_normal'].apply(lambda x: fillna())
# df.head(100)

# %% [markdown]
# # Extract dimensions

# %%
def extract_dim(text):
  patterns = {
  'name': r'The\s+(.*?)\s+has',
  "length": r"length\s+of\s+(\d+)\s+mm",
  'measurement': r'measurement\s+of\s+(\d+)\s+millimeters',
  "height": r"height\s+of\s+(\d+)\s+mm",
  "width": r"width\s+of\s+(\d+)\s+mm",
  "ground_clearance": r"ground\s+clearance\s+of\s+(\d+)\s+cm",
  "category": r"category\s+of\s+(.*?)\."
  }

  car_info = {}

  for key, pattern in patterns.items():
    match = re.search(pattern, text)
    if match:
      car_info[key] = match.group(1) # Convert matched value to integer
    else:
      car_info[key] = None  # Set missing values to None

  return list(car_info.values()), list(car_info.keys())

# %%
columns = extract_dim(df['description'][0])[1]
for i in columns:
  df[i] = df['description'].apply(lambda x: extract_dim(x)[0][columns.index(i)])
df.drop(['boot_space', 'description'], axis = 1).head(10)
# Out:
#   boot_space_5 boot_5_hybrid boot_space_7                      name length  \
# 0          466           466                           Hyundai Kona   4355
# 1          500           430                        Renault Austral   4510
# 2          591           540                           Kia Sportage   4515
# 3          500                                    Alfa-Romeo Tonale   4530
# 4                                                 Volkswagen Tiguan   4540
# 5          466                                            LynkCo 01   4541
# 6          520                                         Peugeot 3008   4542
# 7          404                             Mitsubishi Eclipse Cross   4545
# 8          565           565          160              Dacia Jogger   4547
# 9          560                                               BMW X2   4554
#
#   measurement height width ground_clearance      category
# 0        None   1575  1825               16  mid-size SUV
# 1        2083   1618  1825               17  mid-size SUV
# 2        None   1645  1865               17  mid-size SUV
# 3        None   1600  1840             None  mid-size SUV
# 4        None   1670  1840             None  mid-size SUV
# 5        2141   1694  1857               21  mid-size SUV
# 6        2108   1641  1895             None  mid-size SUV
# 7        None   1685  1805               19  mid-size SUV
# 8        2007   1632  1784               20  mid-size SUV
# 9        2104   1590  1845               20  mid-size SUV

# %%
pattern = r"^(.*?)\s+(.*)$"
df[['brand', 'model']] = df['name'].str.extract(pattern, expand=True)

df = df[['brand', 'model', 'category', 'boot_space_5', 'boot_5_hybrid',
       'boot_space_7', 'length', 'measurement', 'height', 'width',
       'ground_clearance']]

df.head(10)
# Out:
#         brand          model      category boot_space_5 boot_5_hybrid  \
# 0     Hyundai           Kona  mid-size SUV          466           466
# 1     Renault        Austral  mid-size SUV          500           430
# 2         Kia       Sportage  mid-size SUV          591           540
# 3  Alfa-Romeo         Tonale  mid-size SUV          500
# 4  Volkswagen         Tiguan  mid-size SUV
# 5      LynkCo             01  mid-size SUV          466
# 6     Peugeot           3008  mid-size SUV          520
# 7  Mitsubishi  Eclipse Cross  mid-size SUV          404
# 8       Dacia         Jogger  mid-size SUV          565           565
# 9         BMW             X2  mid-size SUV          560
#
#   boot_space_7 length measurement height width ground_clearance
# 0                4355        None   1575  1825               16
# 1                4510        2083   1618  1825               17
# 2                4515        None   1645  1865               17
# 3                4530        None   1600  1840             None
# 4                4540        None   1670  1840             None
# 5                4541        2141   1694  1857               21
# 6                4542        2108   1641  1895             None
# 7                4545        None   1685  1805               19
# 8          160   4547        2007   1632  1784               20
# 9                4554        2104   1590  1845               20

# %% [markdown]
# # Imputing missing values of measurement.

# %%
df['mirrors'] = (pd.to_numeric(df['measurement'], errors='coerce') - df['width']).fillna(np.NaN)

# %%
df['mirror_rate'] = pd.to_numeric(df['mirrors'], errors = 'coerce') / df['width']
df['measurement']  = df['measurement'].replace('', np.NaN)
df['ground_clearance']  = df['ground_clearance'].replace('', np.NaN)
df['boot_mean']  = df['boot_mean'].replace('None', np.NaN)
df['boot_normal']  = df['boot_normal'].replace('None', np.NaN)

# %%
df['mirror_rate'].fillna(np.mean(df['mirror_rate']), inplace=True)
df['measurement'].fillna(round((df['width'] * (1+ df['mirror_rate'])), 0), inplace=True)

# %% [markdown]
# # Extract brand and model

# %%
# Define a regular expression pattern
pattern = r"^(.*?)\s+(.*)$"

# Extract brand and model using str.extract
df[['brand', 'model']] = df['name'].str.extract(pattern, expand=True)

# %%
df.columns

# %%
df = df[['brand', 'model', 'category', 'length', 'height', 'width', 'measurement',
       'boot_normal', 'boot_mean', 'ground_clearance', 'mirrors',
       'mirror_rate']]
df.head(100)
