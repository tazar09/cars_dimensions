# %% [markdown]
# <a href="https://colab.research.google.com/github/tazar09/cars_dimensions/blob/main/midsize_05-feb2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Scrapping the website

# %%
url = 'https://www.automobiledimension.com/compact-suv.php'
h3 = requests.get(url, verify = False)
html_content = h3.text

# %% [markdown]
# # Creating BeautifulSoup objects

# %%
soup = BeautifulSoup(html_content, 'html.parser')
main_table = soup.find('main')

# %%
temp_list = []
for i in main_table.find_all('div', class_ = 'unit'):
  link = str(i.a['href'])
  temp_list.append('https://www.automobiledimension.com' + link)
temp_list[0:3]
# Out:
# ['https://www.automobiledimension.com/model/ford/puma',
#  'https://www.automobiledimension.com/model/audi/q2',
#  'https://www.automobiledimension.com/model/nissan/juke']

# %% [markdown]
# # Extract model description

# %%
def extract_main_text(text):
  search = text.find('div', class_ = 'interior-text')
  return search.text

# %%
def extract_boot_space(text):
  search = text.find_all('figcaption')[1]
  boot_space = search.text
  return boot_space

# %%
main_text_list = []
boot_space_list = []
for i in temp_list:
  content = requests.get(i, verify = False)
  content = BeautifulSoup(content.text, 'html.parser')
  main_text_list.append(extract_main_text(content))
  boot_space_list.append(extract_boot_space(content))

# %% [markdown]
# # Creating dataframe

# %%
df = pd.DataFrame({'description': main_text_list, 'boot_space': boot_space_list})

# %%
def average(text):
  min, max = text.split('-')
  average = (int(max) + int(min))/2
  return average, int(min)

# %%
df['boot_space'] = df['boot_space'].str.replace('Boot space: ', '')
df['boot_space'] = df['boot_space'].str.replace(' liters.','')
df['boot_space'] = df['boot_space'].apply(lambda x: x.replace('* - ', '-') if len(x)>3 else x)

# %%
df['boot_mean'] = df['boot_space'].apply(lambda x: average(x)[0] if len(x) > 3 else int(x))
df['boot_normal'] = df['boot_space'].apply(lambda x: average(x)[1] if len(x) > 3 else int(x))

# %%
df.drop('boot_space', axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                          description  boot_mean  boot_normal
# 0  The Ford Puma has a length of 4207 mm, a heigh...      428.5          401
# 1  The Audi Q2 has a length of 4208 mm, a height ...      405.0          405
# 2  The Nissan Juke has a length of 4210 mm, a hei...      388.0          354
# 3  The Opel Crossland has a length of 4212 mm, a ...      410.0          410
# 4  The SsangYong Tivoli has a length of 4225 mm, ...      427.0          427

# %% [markdown]
# # Extract dimensions

# %%
def extract_dim(text):
  patterns = {
  'name': r'The\s+(.*?)\s+has',
  "length": r"length\s+of\s+(\d+)\s+mm",
  'measurement': r'measurement\s+of\s+(\d+)\s+millimeters',
  "height": r"height\s+of\s+(\d+)\s+mm",
  "width": r"width\s+of\s+(\d+)\s+mm",
  "ground_clearance": r"ground\s+clearance\s+of\s+(\d+)\s+cm",
  "category": r"category\s+of\s+(.*?)\."
  }

  car_info = {}

  for key, pattern in patterns.items():
    match = re.search(pattern, text)
    if match:
      car_info[key] = match.group(1) # Convert matched value to integer
    else:
      car_info[key] = None  # Set missing values to None

  return list(car_info.values()), list(car_info.keys())

# %%
columns = extract_dim(df['description'][0])[1]
for i in columns:
  df[i] = df['description'].apply(lambda x: extract_dim(x)[0][columns.index(i)])

# %%
# reordering the columns

df = df[['name', 'category','length', 'height',
       'width','measurement', 'boot_normal', 'boot_mean', 'ground_clearance']]

df.head()
# Out:
#                name     category length height width measurement  boot_normal  \
# 0         Ford Puma  compact SUV   4207   1537  1805        1930          401
# 1           Audi Q2  compact SUV   4208   1508  1794        2009          405
# 2       Nissan Juke  compact SUV   4210   1595  1800        1983          354
# 3    Opel Crossland  compact SUV   4212   1605  1765        1976          410
# 4  SsangYong Tivoli  compact SUV   4225   1621  1810        None          427
#
#    boot_mean ground_clearance
# 0      428.5               16
# 1      405.0               15
# 2      388.0               17
# 3      410.0               17
# 4      427.0               18

# %%
numeric_columns = df.columns[2:]
for i in numeric_columns:
  df[i] = df[i].apply(lambda x: np.NaN if (x == None) else int(x))

# %% [markdown]
# # Imputing missing values of measurement.

# %%
df['mirrors'] = (pd.to_numeric(df['measurement'], errors='coerce') - df['width']).fillna(np.NaN)

# %%
df['mirror_rate'] = pd.to_numeric(df['mirrors'], errors = 'coerce') / df['width']
df['measurement']  = df['measurement'].replace('', np.NaN)
df['ground_clearance']  = df['ground_clearance'].replace('', np.NaN)
df['boot_mean']  = df['boot_mean'].replace('None', np.NaN)
df['boot_normal']  = df['boot_normal'].replace('None', np.NaN)

# %%
df['mirror_rate'].fillna(np.mean(df['mirror_rate']), inplace=True)
df['measurement'].fillna(round((df['width'] * (1+ df['mirror_rate'])), 0), inplace=True)

# %% [markdown]
# # Extract brand and model

# %%
# Define a regular expression pattern
pattern = r"^(.*?)\s+(.*)$"

# Extract brand and model using str.extract
df[['brand', 'model']] = df['name'].str.extract(pattern, expand=True)

# %%
df.columns
# Out:
# Index(['name', 'category', 'length', 'height', 'width', 'measurement',
#        'boot_normal', 'boot_mean', 'ground_clearance', 'mirrors',
#        'mirror_rate', 'brand', 'model'],
#       dtype='object')

# %%
df = df[['brand', 'model', 'category', 'length', 'height', 'width', 'measurement',
       'boot_normal', 'boot_mean', 'ground_clearance', 'mirrors',
       'mirror_rate']]
df.head(100)
# Out:
#             brand               model      category  length  height  width  \
# 0            Ford                Puma   compact SUV    4207    1537   1805
# 1            Audi                  Q2   compact SUV    4208    1508   1794
# 2          Nissan                Juke   compact SUV    4210    1595   1800
# 3            Opel           Crossland   compact SUV    4212    1605   1765
# 4       SsangYong              Tivoli   compact SUV    4225    1621   1810
# 5         Renault              Captur   compact SUV    4227    1566   1797
# 6      Mitsubishi                 ASX   compact SUV    4227    1566   1797
# 7           Volvo                EX30   compact SUV    4233    1549   1836
# 8            Jeep            Renegade   compact SUV    4236    1697   1805
# 9      Volkswagen               T-Roc   compact SUV    4236    1573   1819
# 10          Skoda               Kamiq   compact SUV    4241    1553   1793
# 11           Fiat                500X   compact SUV    4264    1595   1796
# 12          Smart                  #1   compact SUV    4270    1636   1822
# 13     Volkswagen               Taigo   compact SUV    4271    1515   1757
# 14         Suzuki             S-Cross   compact SUV    4300    1585   1785
# 15        Peugeot                2008   compact SUV    4304    1550   1770
# 16             MG                  ZS   compact SUV    4323    1653   1809
# 17          Honda                HR-V   compact SUV    4340    1582   1790
# 18          Dacia              Duster   compact SUV    4340    1660   1810
# 19         Toyota                C-HR   compact SUV    4360    1570   1830
# 20     Land-Rover  Range Rover Evoque   compact SUV    4371    1649   1904
# 21           Seat               Ateca   compact SUV    4381    1615   1841
# 22          CUPRA               Ateca   compact SUV    4386    1613   1841
# 23           Fiat          Tipo Cross   compact SUV    4386    1556   1802
# 24          Honda               e:Ny1   compact SUV    4387    1584   1790
# 25          Skoda               Karoq   compact SUV    4390    1603   1841
# 26            Kia               XCeed   compact SUV    4395    1483   1826
# 27         Jaguar              E-PACE   compact SUV    4395    1648   1900
# 28          Mazda               CX-30   compact SUV    4395    1540   1795
# 29           Jeep             Compass   compact SUV    4395    1640   1820
# 30           Ford        Focus Active   compact SUV    4397    1502   1844
# 31          Smart                  #3   compact SUV    4400    1556   1844
# 32  Mercedes-Benz                 GLA   compact SUV    4410    1616   1834
# 33            Kia                Niro   compact SUV    4420    1570   1825
# 34         Nissan             Qashqai   compact SUV    4425    1635   1838
# 35           MINI          Countryman   compact SUV    4433    1656   1843
# 36          Volvo                XC40   compact SUV    4440    1652   1863
# 37        Peugeot                3008  mid-size SUV    4542    1641   1895
# 38          CUPRA           Formentor   compact SUV    4450    1528   1839
# 39      SsangYong             Korando   compact SUV    4450    1629   1870
# 40         Toyota       Corolla Cross   compact SUV    4460    1620   1825
# 41           Ford            Explorer   compact SUV    4460    1600   1870
# 42  Mercedes-Benz                 EQA   compact SUV    4463    1620   1834
# 43           Opel           Grandland   compact SUV    4477    1609   1856
# 44      SsangYong        Tivoli Grand   compact SUV    4480    1660   1810
# 45           Audi                  Q3   compact SUV    4484    1585   1856
# 46          Lexus                  UX   compact SUV    4495    1540   1840
# 47         Subaru           Crosstrek   compact SUV    4495    1600   1800
# 48           Audi        Q3 Sportback   compact SUV    4500    1556   1843
# 49        Citroen         C5 Aircross   compact SUV    4500    1689   1840
# 50            BMW                  X1   compact SUV    4500    1642   1845
# 51        Hyundai              Tucson   compact SUV    4500    1650   1865
#
#     measurement  boot_normal  boot_mean  ground_clearance  mirrors  \
# 0        1930.0          401        428              16.0    125.0
# 1        2009.0          405        405              15.0    215.0
# 2        1983.0          354        388              17.0    183.0
# 3        1976.0          410        410              17.0    211.0
# 4        2018.0          427        427              18.0      NaN
# 5        2003.0          265        335              17.0    206.0
# 6        2003.0          265        333              17.0    206.0
# 7        2032.0          318        318              17.0    196.0
# 8        2013.0          330        340              17.0      NaN
# 9        2012.0          445        445              16.0    193.0
# 10       1988.0          400        400              18.0    195.0
# 11       2025.0          350        350              16.0    229.0
# 12       2032.0          288        288               NaN      NaN
# 13       1995.0          440        440               NaN    238.0
# 14       1990.0          430        430              18.0      NaN
# 15       1987.0          405        419              17.0    217.0
# 16       2048.0          448        448              16.0    239.0
# 17       2028.0          335        335              19.0    238.0
# 18       2060.0          472        472              21.0    250.0
# 19       2041.0          310        349               NaN      NaN
# 20       2100.0          472        472              21.0    196.0
# 21       2078.0          510        510              18.0    237.0
# 22       2078.0          485        485              17.0    237.0
# 23       2002.0          440        440              16.0    200.0
# 24       2028.0          361        361              14.0    238.0
# 25       2025.0          521        521              17.0    184.0
# 26       2055.0          291        358              17.0    229.0
# 27       2088.0          394        394              21.0    188.0
# 28       2002.0          430        430              17.0      NaN
# 29       2115.0          420        429              20.0    295.0
# 30       1979.0          392        392              16.0    135.0
# 31       2056.0          385        385               NaN      NaN
# 32       2020.0          385        410              17.0    186.0
# 33       2035.0          348        399              16.0      NaN
# 34       2084.0          480        480              18.0    246.0
# 35       2055.0          460        460               NaN      NaN
# 36       2034.0          450        451              21.0    171.0
# 37       2108.0          520        520               NaN    213.0
# 38       1992.0          345        397               NaN    153.0
# 39       2085.0          551        551              17.0      NaN
# 40       2035.0          433        433               NaN      NaN
# 41       2085.0          470        470               NaN      NaN
# 42       2020.0          340        340              18.0    186.0
# 43       2098.0          390        452              20.0    242.0
# 44       2018.0          574        574              17.0      NaN
# 45       2024.0          380        455              17.0    168.0
# 46       2052.0          367        343              16.0      NaN
# 47       2020.0          315        315              22.0    220.0
# 48       2022.0          380        455              17.0    179.0
# 49       2099.0          460        520              23.0    259.0
# 50       2104.0          490        515              20.0    259.0
# 51       2080.0          546        572              17.0      NaN
#
#     mirror_rate
# 0      0.069252
# 1      0.119844
# 2      0.101667
# 3      0.119547
# 4      0.115118
# 5      0.114636
# 6      0.114636
# 7      0.106754
# 8      0.115118
# 9      0.106102
# 10     0.108756
# 11     0.127506
# 12     0.115118
# 13     0.135458
# 14     0.115118
# 15     0.122599
# 16     0.132117
# 17     0.132961
# 18     0.138122
# 19     0.115118
# 20     0.102941
# 21     0.128734
# 22     0.128734
# 23     0.110988
# 24     0.132961
# 25     0.099946
# 26     0.125411
# 27     0.098947
# 28     0.115118
# 29     0.162088
# 30     0.073210
# 31     0.115118
# 32     0.101418
# 33     0.115118
# 34     0.133841
# 35     0.115118
# 36     0.091787
# 37     0.112401
# 38     0.083197
# 39     0.115118
# 40     0.115118
# 41     0.115118
# 42     0.101418
# 43     0.130388
# 44     0.115118
# 45     0.090517
# 46     0.115118
# 47     0.122222
# 48     0.097124
# 49     0.140761
# 50     0.140379
# 51     0.115118
